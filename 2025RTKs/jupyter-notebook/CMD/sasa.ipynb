# %%
import numpy as np
import matplotlib.pylab as plt 
import pandas as pd
import pickle

# %%
ls
# Out:
# SASA.sh*  surf_4agc_nojm.dat  surf_pocket_jm.dat  Untitled.ipynb

# %%
pwd
# Out:
# '/home/xhchen/VEGFR2/cmd-withJM_withoutJM/analysis/SASA'

# %%
pocket_sasa_jm = np.loadtxt('/home/xhchen/VEGFR2/cmd-withJM_withoutJM/analysis/SASA/surf_pocket_jm.dat',comments = "#")
pocket_sasa_nojm = np.loadtxt('/home/xhchen/VEGFR2/cmd-withJM_withoutJM/analysis/SASA/surf_4agc_nojm.dat',comments = "#")

# %%
plt.figure(figsize=(3,2.3),dpi=200)
plt.hist(pocket_sasa_jm [:,1], bins=30, alpha=0.4, label='with JM',color='royalblue',density = True)#density:数据的归一化处理
plt.hist(pocket_sasa_nojm[:,1], bins=30, alpha=0.4, label='no JM',color='red',density = True)
plt.legend(loc=1,fontsize = 7,ncols=1)
plt.xlabel(r"SASA ($\mathrm{\AA}^2$)", fontsize=8)
plt.ylabel("density",fontsize = 8)
plt.xticks(fontsize = 8)
plt.yticks(fontsize = 8)
plt.title('SASA-pocket',fontsize=8)
plt.savefig('/home/xhchen/VEGFR2/cmd-withJM_withoutJM/analysis/SASA/sasa-pocket.svg',bbox_inches='tight',transparent='Ture')
plt.savefig('/home/xhchen/VEGFR2/cmd-withJM_withoutJM/analysis/SASA/sasa-pocket.png',bbox_inches='tight',transparent='Ture')
