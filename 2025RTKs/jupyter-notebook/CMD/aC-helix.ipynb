# %%
import numpy as np
import matplotlib.pylab as plt 
import pandas as pd
import pickle

# %%
pwd
# Out:
# '/home/xhchen/VEGFR2/cmd-withJM_withoutJM/analysis/aC-helix'

# %%
#C-helix构象(参考JCIM中的距离)
distance1_k79_e96 = np.loadtxt("/home/xhchen/VEGFR2/cmd-withJM_withoutJM/cmd_jm_4agc/1_1μs_4agc_jm_MD/analysis/distance_k79-e96_remove100ns.dat",comments = "#")
distance2_k79_e96 = np.loadtxt("/home/xhchen/VEGFR2/cmd-withJM_withoutJM/cmd_jm_4agc/2_1μs_4agc_jm_MD/analysis/distance_k79-e96_remove100ns.dat",comments = "#")
distance3_k79_e96 = np.loadtxt("/home/xhchen/VEGFR2/cmd-withJM_withoutJM/cmd_jm_4agc/3_1μs_4agc_jm_MD/analysis/distance_k79-e96_remove100ns.dat",comments = "#")
distance4_k79_e96 = np.loadtxt("/home/xhchen/VEGFR2/cmd-withJM_withoutJM/cmd_jm_4agc/4_1μs_4agc_jm_MD/analysis/distance_k79-e96_remove100ns.dat",comments = "#")
distance5_k79_e96 = np.loadtxt("/home/xhchen/VEGFR2/cmd-withJM_withoutJM/cmd_jm_4agc/5_1μs_4agc_jm_MD/analysis/distance_k79-e96_remove100ns.dat",comments = "#")
distance1_k35_e52_without_jm =np.loadtxt("/home/xhchen/VEGFR2/cmd-withJM_withoutJM/cmd_4agc/1_4agc/analysis/distance_k79-e96_remove100ns.dat",comments = "#")
distance2_k35_e52_without_jm =np.loadtxt("/home/xhchen/VEGFR2/cmd-withJM_withoutJM/cmd_4agc/2_4agc/analysis/distance_k79-e96_remove100ns.dat",comments = "#")
distance3_k35_e52_without_jm =np.loadtxt("/home/xhchen/VEGFR2/cmd-withJM_withoutJM/cmd_4agc/3_4agc/analysis/distance_k79-e96_remove100ns.dat",comments = "#")

# %%
plt.figure(figsize=(3,2.3),dpi=200)
with_jm_distance=np.vstack((distance1_k79_e96,distance2_k79_e96,distance3_k79_e96,distance4_k79_e96,distance5_k79_e96))
without_jm_distance=np.vstack((distance1_k35_e52_without_jm,distance2_k35_e52_without_jm,distance3_k35_e52_without_jm))
plt.hist(with_jm_distance[:,1], bins=30, alpha=0.4, label='with JM',color='royalblue',density = True)#density:数据的归一化处理
plt.hist(without_jm_distance[:,1], bins=30, alpha=0.4, label='no JM',color='red',density = True)
plt.legend(loc=1,fontsize = 7,ncols=1)
plt.xlabel("distance($\AA$)",fontsize = 8)
plt.ylabel("density",fontsize = 8)
plt.xticks(fontsize = 8)
plt.yticks(fontsize = 8)
plt.title('K868-E885',fontsize=8)
plt.savefig('/home/xhchen/VEGFR2/cmd-withJM_withoutJM/analysis/aC-helix/hist_K79-E96.svg',bbox_inches='tight',transparent='Ture')
plt.savefig('/home/xhchen/VEGFR2/cmd-withJM_withoutJM/analysis/aC-helix/hist_K79-E96.png',bbox_inches='tight',transparent='Ture')
