# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
#import scienceplots as sp
#plt.style.use(['nature'])
from scipy import stats

# %%
plt.rcParams.update({
    'font.size':5,
    'axes.labelsize':5,
    'axes.titlesize':5,
    'legend.fontsize':4,
    'xtick.labelsize':4,
    'ytick.labelsize':4,
    'figure.dpi':300,
    'savefig.dpi':300,
    'axes.linewidth':0.4,
    'lines.linewidth':0.5,
})
plt.rcParams['axes.labelpad'] = 1     # 坐标轴标签距离
plt.rcParams['xtick.major.pad'] = 2     # X轴主刻度标签距离
plt.rcParams['ytick.major.pad'] = 2     # Y轴主刻度标签距离
plt.rcParams['axes.titlepad'] = 6      # 标题距离

plt.rcParams['axes.spines.bottom'] = False
plt.rcParams['axes.spines.right'] = False

# %%
#7z1x average RMSF Difference (monomer - complex) 290K
plt.figure(figsize=(2,0.3),dpi=300)
plt.tick_params(axis='both', which='major', width=0.5, length=2)
energy_data = [-0.436,-0.360,-0.458,-0.267,-0.235,-0.483,-0.318,-0.588,-0.320,-0.567]
width = 0.7
labels = ['7Z1A','7Z1B','7Z1C','7Z1D','7Z1E','H11D4','H11H4','H11H4Y101A','H11H4Y104F','H11H4Y104S']
#plt.ylabel('Average RMSF Difference ($\AA$)',fontsize=10)
#colors=['green','blue','royalblue','cornflowerblue','skyblue','black','lightsalmon','salmon','tomato','red']
colors=['#7FCBBC','#FBFFA5','#F8A452','#F5695E','#D0D0D0','#6DA1C8','#B3ACD3','#F7BFDD','#A8D958','#50E2DE']
barlist = plt.bar(labels,energy_data,width)
plt.xticks(labels, rotation=20,)
#plt.yticks(range(-1,10,10),fontsize=8)
for i, j in enumerate(barlist):
    j.set_color(colors[i])
plt.ylim([-1,0])
#plt.title('290K',fontsize=9)
plt.axhline(-0.4032,color='black',lw=0.5,ls='--')
plt.text(0.01, 0.3, "-0.403", transform=plt.gca().transAxes,fontsize=4)
#plt.savefig('/home/teliu/work/nanobody/image/draft/fig4/average-7z1x-290k.png',bbox_inches='tight',transparent=True)

# %%
#7z1x average RMSF Difference (monomer - complex) 300K
plt.figure(figsize=(2,0.3),dpi=300)
plt.tick_params(axis='both', which='major', width=0.5, length=2)
energy_data = [-0.146,-0.095,-0.141,-0.128,-0.371,-0.205,-0.111,-0.162,-0.206,-0.174]
width = 0.7
labels = ['7Z1A','7Z1B','7Z1C','7Z1D','7Z1E','H11D4','H11H4','H11H4Y101A','H11H4Y104F','H11H4Y104S']
#plt.ylabel('Average RMSF Difference ($\AA$)',fontsize=10)
#colors=['green','blue','royalblue','cornflowerblue','skyblue','black','lightsalmon','salmon','tomato','red']
colors=['#7FCBBC','#FBFFA5','#F8A452','#F5695E','#D0D0D0','#6DA1C8','#B3ACD3','#F7BFDD','#A8D958','#50E2DE']
barlist = plt.bar(labels,energy_data,width)
plt.xticks(labels, rotation=20)
#plt.yticks(range(-1,10,10),fontsize=8)
for i, j in enumerate(barlist):
    j.set_color(colors[i])
plt.ylim([-1,0])
#plt.title('300K',fontsize=9)
plt.axhline(-0.1739,color='black',lw=0.5,ls='--')
plt.text(0.01, 0.55, "-0.174", transform=plt.gca().transAxes,fontsize=4)
#plt.savefig('/home/teliu/work/nanobody/image/draft/fig4/average-7z1x-300k.png',bbox_inches='tight',transparent=True)

# %%
#7z1x average RMSF Difference (monomer - complex) 315K
plt.figure(figsize=(2,0.3),dpi=300)
plt.tick_params(axis='both', which='major', width=0.5, length=2)
energy_data = [-0.793,-0.228,-0.290,-0.341,-0.624,-0.259,-0.305,-0.370,-0.718,-0.196]
width = 0.7
labels = ['7Z1A','7Z1B','7Z1C','7Z1D','7Z1E','H11D4','H11H4','H11H4Y101A','H11H4Y104F','H11H4Y104S']
#plt.ylabel('Average RMSF Difference ($\AA$)',fontsize=10)
#colors=['green','blue','royalblue','cornflowerblue','skyblue','black','lightsalmon','salmon','tomato','red']
colors=['#7FCBBC','#FBFFA5','#F8A452','#F5695E','#D0D0D0','#6DA1C8','#B3ACD3','#F7BFDD','#A8D958','#50E2DE']
barlist = plt.bar(labels,energy_data,width)
plt.xticks(labels, rotation=20)
#plt.yticks(range(-1,10,10),fontsize=8)
for i, j in enumerate(barlist):
    j.set_color(colors[i])
plt.ylim([-1,0])
#plt.title('315K',fontsize=9)
plt.axhline(-0.4124,color='black',lw=0.5,ls='--')
plt.text(0.01, 0.3, "-0.412", transform=plt.gca().transAxes,fontsize=4)
#plt.savefig('/home/teliu/work/nanobody/image/draft/fig4/average-7z1x-315k.png',bbox_inches='tight',transparent=True)

# %%
#2p4x average RMSF Difference (monomer - complex) 290K
plt.figure(figsize=(2,0.3),dpi=300)
plt.tick_params(axis='both', which='major', width=0.5, length=2)
energy_data = [-0.214,-0.212,-0.189,-0.184,-0.180,-0.254,-0.168,-0.144,-0.101]
width = 0.7
labels = ['2P42','2P43','2P44','2P45','2P46','2P47','2P48','2P49','2P4A']
#plt.ylabel('Average RMSF Difference ($\AA$)',fontsize=10)
#colors=['green','blue','royalblue','cornflowerblue','skyblue','lightsalmon','salmon','tomato','red']
colors=['#7FCBBC','#FBFFA5','#F8A452','#F5695E','#D0D0D0','#6DA1C8','#B3ACD3','#F7BFDD','#A8D958','#50E2DE']
barlist = plt.bar(labels,energy_data,width)
plt.xticks(labels, rotation=20)
#plt.yticks(range(-1,10,10),fontsize=8)
for i, j in enumerate(barlist):
    j.set_color(colors[i])
plt.ylim([-1,0])
#plt.title('290K',fontsize=9)
plt.axhline(-0.1829,color='black',lw=0.5,ls='--')
plt.text(0.01, 0.55, "-0.183", transform=plt.gca().transAxes,fontsize=4)
#plt.savefig('/home/teliu/work/nanobody/image/draft/fig4/average-2p4x-290k.png',bbox_inches='tight',transparent=True)

# %%
#2p4x average RMSF Difference (monomer - complex) 300K
plt.figure(figsize=(2,0.3),dpi=300)
plt.tick_params(axis='both', which='major', width=0.5, length=2)
energy_data = [-0.155,-0.089,-0.036,-0.309,-0.195,-0.133,-0.221,-0.099,-0.021]
width = 0.7
labels = ['2P42','2P43','2P44','2P45','2P46','2P47','2P48','2P49','2P4A']
#plt.ylabel('Average RMSF Difference ($\AA$)',fontsize=10)
#colors=['green','blue','royalblue','cornflowerblue','skyblue','lightsalmon','salmon','tomato','red']
colors=['#7FCBBC','#FBFFA5','#F8A452','#F5695E','#D0D0D0','#6DA1C8','#B3ACD3','#F7BFDD','#A8D958','#50E2DE']
barlist = plt.bar(labels,energy_data,width)
plt.xticks(labels, rotation=20)
#plt.yticks(range(-1,10,10),fontsize=8)
for i, j in enumerate(barlist):
    j.set_color(colors[i])
plt.ylim([-1,0])
#plt.title('300K',fontsize=9)
plt.axhline(-0.1398,color='black',lw=0.5,ls='--')
plt.text(0.01, 0.6, "-0.139", transform=plt.gca().transAxes,fontsize=4)
#plt.savefig('/home/teliu/work/nanobody/image/draft/fig4/average-2p4x-300k.png',bbox_inches='tight',transparent=True)

# %%
#2p4x average RMSF Difference (monomer - complex) 315K
plt.figure(figsize=(2,0.3),dpi=300)
plt.tick_params(axis='both', which='major', width=0.5, length=2)
energy_data = [-0.069,0.109,-0.142,0.014,-0.006,-0.083,-0.081,-0.017,-0.042]
width = 0.7
labels = ['2P42','2P43','2P44','2P45','2P46','2P47','2P48','2P49','2P4A']
#plt.ylabel('Average RMSF Difference ($\AA$)',fontsize=10)
#colors=['green','blue','royalblue','cornflowerblue','skyblue','lightsalmon','salmon','tomato','red']
colors=['#7FCBBC','#FBFFA5','#F8A452','#F5695E','#D0D0D0','#6DA1C8','#B3ACD3','#F7BFDD','#A8D958','#50E2DE']
barlist = plt.bar(labels,energy_data,width)
plt.xticks(labels, rotation=20)
for i, j in enumerate(barlist):
    j.set_color(colors[i])
plt.ylim([-1,0])
#plt.title('315K',fontsize=9)
plt.axhline(-0.035,color='black',lw=0.5,ls='--')
plt.text(0.01, 0.6, "-0.035", transform=plt.gca().transAxes,fontsize=4)
plt.savefig('/home/teliu/work/nanobody/image/draft/fig4/average-2p4x-315k.png',bbox_inches='tight',transparent=True)
