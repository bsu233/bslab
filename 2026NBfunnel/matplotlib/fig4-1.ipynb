# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
#import scienceplots as sp
#plt.style.use(['nature'])
from scipy import stats

# %%
plt.rcParams.update({
    'font.size':10,
    'axes.labelsize':10,
    'axes.titlesize':6,
    'legend.fontsize':10,
    'xtick.labelsize':10,
    'ytick.labelsize':10,
    'figure.dpi':300,
    'savefig.dpi':300,
    'axes.linewidth':0.5,
    'lines.linewidth':1,
})
plt.rcParams['axes.labelpad'] = 1     # 坐标轴标签距离
plt.rcParams['xtick.major.pad'] = 2     # X轴主刻度标签距离
plt.rcParams['ytick.major.pad'] = 2     # Y轴主刻度标签距离
plt.rcParams['axes.titlepad'] = 6      # 标题距离

plt.rcParams['axes.spines.top'] = False
plt.rcParams['axes.spines.right'] = False

# %%
cm = 1/2.54

# %%
#7Z1A com and monomer RMSF
rmsf7z1e300com=np.loadtxt('/home/teliu/work/nanobody/newgroup/pnas/md/com/300/7z1e/rmsf.dat',comments="#")
rmsf7z1e300nano=np.loadtxt('/home/teliu/work/nanobody/newgroup/pnas/md/com/300/nanobody/rmsf/7z1e_final.dat',comments="#")
alignrmsf7z1e=np.loadtxt('/home/teliu/work/nanobody/newgroup/pnas/md/com/300/7z1e/com-rmsf.dat',comments="#")
plt.figure(figsize=(10*cm,4*cm),dpi=300)
plt.tick_params(axis='both', which='major', width=0.5, length=2)
lw=0.5
plt.plot(rmsf7z1e300com[:,0],rmsf7z1e300com[:,1],'b',lw=1, label='complex')
plt.plot(rmsf7z1e300nano[:,0],rmsf7z1e300nano[:,1],'cyan',lw=1, label='monomer')
plt.plot(rmsf7z1e300com[:,0],rmsf7z1e300nano[:,1]-rmsf7z1e300com[:,1],'green',marker='o',markerfacecolor='green',markeredgewidth=0.1,markersize='0.7',label='monomer-complex')
plt.plot(alignrmsf7z1e[:,0],alignrmsf7z1e[:,1],'b',lw=1, label='align',ls='--')
plt.axhline(0,color='black',lw=0.5,ls='--')
plt.xlim([197,324])
plt.ylim([-2,4])
plt.yticks([-2, 0, 2,4]) 
#plt.legend(loc=1,fontsize=2)
plt.ylabel('RMSF ($\AA$)')
plt.xlabel('Residue Number')
#plt.yticks(fontsize=5)
#plt.xticks(fontsize=5)
plt.savefig('/home/teliu/work/nanobody/image/draft/fig4/7z1e.png',bbox_inches='tight',transparent=True)
# Out:
# <>:17: SyntaxWarning: invalid escape sequence '\A'
# <>:17: SyntaxWarning: invalid escape sequence '\A'
# /tmp/ipykernel_163989/851148869.py:17: SyntaxWarning: invalid escape sequence '\A'
#   plt.ylabel('RMSF ($\AA$)')

# %%
#7Z1A com and monomer RMSF
rmsf2p44300com=np.loadtxt('/home/teliu/work/nanobody/newgroup/2p4x/300/2p44/rmsf.dat',comments="#")
rmsf2p44300nano=np.loadtxt('/home/teliu/work/nanobody/newgroup/2p4x/300/nanobody/rmsf/2p44_final.dat',comments="#")
alignrmsf2p44=np.loadtxt('/home/teliu/work/nanobody/newgroup/2p4x/300/2p44/com-rmsf.dat',comments="#")
plt.figure(figsize=(10*cm,4*cm),dpi=300)
plt.tick_params(axis='both', which='major', width=0.5, length=2)
lw=0.5
plt.plot(rmsf2p44300com[:,0],rmsf2p44300com[:,1],'b',lw=1, label='complex')
plt.plot(rmsf2p44300nano[:,0],rmsf2p44300nano[:,1],'cyan',lw=1, label='monomer')
plt.plot(rmsf2p44300com[:,0],rmsf2p44300nano[:,1]-rmsf2p44300com[:,1],'green',marker='o',markeredgewidth=0.1,markersize='0.7',label='monomer-complex')
plt.plot(alignrmsf2p44[:,0],alignrmsf2p44[:,1],'b',ls='--',lw=1, label='align')
plt.axhline(0,color='black',lw=0.5,ls='--')
plt.xlim([125,245])
#plt.xticks([1, 50, 100,120]) 
plt.ylim([-2,4])
#plt.legend(loc=1,fontsize=2)
plt.ylabel('RMSF ($\AA$)')
plt.xlabel('Residue Number')
#plt.yticks(fontsize=5)
#plt.xticks(fontsize=5)
plt.savefig('/home/teliu/work/nanobody/image/draft/fig4/2p44.png',bbox_inches='tight',transparent=True)
# Out:
# <>:17: SyntaxWarning: invalid escape sequence '\A'
# <>:17: SyntaxWarning: invalid escape sequence '\A'
# /tmp/ipykernel_163989/3938660779.py:17: SyntaxWarning: invalid escape sequence '\A'
#   plt.ylabel('RMSF ($\AA$)')

# %%
#285 7z1x
new285rosettamd=np.loadtxt('/home/teliu/work/nanobody/newgroup/pnas/md/com/285/result/285-exp-rosetta',comments="#")
new290rosettamd=np.loadtxt('/home/teliu/work/nanobody/newgroup/pnas/md/com/newnano/290/result/exp-com-rosetta',comments="#")
new295rosettamd=np.loadtxt('/home/teliu/work/nanobody/newgroup/pnas/md/com/295/result/295-exp-rosetta',comments="#")
new300rosettamd=np.loadtxt('/home/teliu/work/nanobody/newgroup/pnas/md/com/newnano/300/result/exp-com-rosetta',comments="#")
new305rosettamd=np.loadtxt('/home/teliu/work/nanobody/newgroup/pnas/md/com/305/result/305-exp-rosetta',comments="#")
new310rosettamd=np.loadtxt('/home/teliu/work/nanobody/newgroup/pnas/md/com/310/result/310-exp-rosetta',comments="#")
new315rosettamd=np.loadtxt('/home/teliu/work/nanobody/newgroup/pnas/md/com/newnano/315/result/exp-com-rosetta',comments="#")
plt.figure(figsize=(10*cm,10*cm),dpi=300)
plt.tick_params(axis='both', which='major', width=0.5, length=2)
# 读取数据
x = new315rosettamd[:,0]
y = new315rosettamd[:,1]
# 计算相关性
corr = np.corrcoef(x, y)[0, 1]
# 绘制散点图
sns.regplot(data=new285rosettamd,x=new285rosettamd[:,0], y=new285rosettamd[:,1], scatter_kws={"s": 3,"color":"blue"},color='blue',ci=None,label="285K")
sns.regplot(data=new290rosettamd,x=new290rosettamd[:,0], y=new290rosettamd[:,1], scatter_kws={"s": 3,"color":"royalblue"},color='royalblue',ci=None,label="290K")
sns.regplot(data=new295rosettamd,x=new295rosettamd[:,0], y=new295rosettamd[:,1], scatter_kws={"s": 3,"color":"cornflowerblue"},color='cornflowerblue',ci=None,label="295K")
sns.regplot(data=new300rosettamd,x=new300rosettamd[:,0], y=new300rosettamd[:,1], scatter_kws={"s": 3,"color":"grey"},color='black',ci=None,label="300K")
sns.regplot(data=new305rosettamd,x=new305rosettamd[:,0], y=new305rosettamd[:,1], scatter_kws={"s": 3,"color":"salmon"},color='salmon',ci=None,label="305K")
sns.regplot(data=new310rosettamd,x=new310rosettamd[:,0], y=new310rosettamd[:,1], scatter_kws={"s": 3,"color":"tomato"},color='tomato',ci=None,label="310K")
sns.regplot(data=new315rosettamd,x=new315rosettamd[:,0], y=new315rosettamd[:,1], scatter_kws={"s": 3,"color":"red"},color='red',ci=None,label="315K")
# 加标题和坐标轴标签
#plt.title("The Correlation of Experiment and Rosetta_MD",fontsize=11)
plt.xlabel('Experimental $\Delta$G (kcal mol$^{-1}$)')
plt.ylabel('Rosetta $\Delta$G (kcal mol$^{-1}$)')
#plt.xticks(fontsize=10)
#plt.yticks(fontsize=10)
plt.xlim([-12,-7])
plt.ylim([-35,-10])
#plt.legend(loc=1,fontsize=5)
# 加相关性数据
#plt.text(0.45, 0.1, "Correlation coefficient: {:.4f}".format(corr), transform=plt.gca().transAxes,fontsize=8)
#plt.text(0.6, 0.05, "$r^2$: {:.4f}".format(corr**2), transform=plt.gca().transAxes,fontsize=8)
# 显⽰图象
#plt.show()
plt.savefig('/home/teliu/work/nanobody/image/draft/fig4/pnas-all-rosetta-md.png',bbox_inches='tight',transparent=True)
# Out:
# <>:26: SyntaxWarning: invalid escape sequence '\D'
# <>:27: SyntaxWarning: invalid escape sequence '\D'
# <>:26: SyntaxWarning: invalid escape sequence '\D'
# <>:27: SyntaxWarning: invalid escape sequence '\D'
# /tmp/ipykernel_163989/345771833.py:26: SyntaxWarning: invalid escape sequence '\D'
#   plt.xlabel('Experimental $\Delta$G (kcal mol$^{-1}$)')
# /tmp/ipykernel_163989/345771833.py:27: SyntaxWarning: invalid escape sequence '\D'
#   plt.ylabel('Rosetta $\Delta$G (kcal mol$^{-1}$)')

# %%
#285 7z1x
n2p4x285rosettamd=np.loadtxt('/home/teliu/work/nanobody/newgroup/2p4x/285/result/285-exp-rosetta',comments="#")
n2p4x290rosettamd=np.loadtxt('/home/teliu/work/nanobody/newgroup/2p4x/290/result/290-exp-rosetta',comments="#")
n2p4x295rosettamd=np.loadtxt('/home/teliu/work/nanobody/newgroup/2p4x/295/result/295-exp-rosetta',comments="#")
n2p4x300rosettamd=np.loadtxt('/home/teliu/work/nanobody/newgroup/2p4x/exp-md-rosetta',comments="#")
n2p4x305rosettamd=np.loadtxt('/home/teliu/work/nanobody/newgroup/2p4x/305/result/305-exp-rosetta',comments="#")
n2p4x310rosettamd=np.loadtxt('/home/teliu/work/nanobody/newgroup/2p4x/310/result/310-exp-rosetta',comments="#")
n2p4x315rosettamd=np.loadtxt('/home/teliu/work/nanobody/newgroup/2p4x/315-exp-rosetta',comments="#")
plt.figure(figsize=(10*cm,10*cm),dpi=300)
plt.tick_params(axis='both', which='major', width=0.5, length=2)
# 读取数据
x = n2p4x285rosettamd[:,0]
y = n2p4x285rosettamd[:,1]
# 计算相关性
corr = np.corrcoef(x, y)[0, 1]
# 绘制散点图
sns.regplot(data=n2p4x285rosettamd,x=n2p4x285rosettamd[:,0], y=n2p4x285rosettamd[:,1], scatter_kws={"s": 3,"color":"blue"},color='blue',ci=None,label="285K")
sns.regplot(data=n2p4x290rosettamd,x=n2p4x290rosettamd[:,0], y=n2p4x290rosettamd[:,1], scatter_kws={"s": 3,"color":"royalblue"},color='royalblue',ci=None,label="290K")
sns.regplot(data=n2p4x295rosettamd,x=n2p4x295rosettamd[:,0], y=n2p4x295rosettamd[:,1], scatter_kws={"s": 3,"color":"cornflowerblue"},color='cornflowerblue',ci=None,label="295K")
sns.regplot(data=n2p4x300rosettamd,x=n2p4x300rosettamd[:,0], y=n2p4x300rosettamd[:,1], scatter_kws={"s": 3,"color":"gray"},color='black',ci=None,label="300K")
sns.regplot(data=n2p4x305rosettamd,x=n2p4x305rosettamd[:,0], y=n2p4x305rosettamd[:,1], scatter_kws={"s": 3,"color":"salmon"},color='salmon',ci=None,label="305K")
sns.regplot(data=n2p4x310rosettamd,x=n2p4x310rosettamd[:,0], y=n2p4x310rosettamd[:,1], scatter_kws={"s": 3,"color":"tomato"},color='tomato',ci=None,label="310K")
sns.regplot(data=n2p4x315rosettamd,x=n2p4x315rosettamd[:,0], y=n2p4x315rosettamd[:,1], scatter_kws={"s": 3,"color":"red"},color='red',ci=None,label="315K")
# 加标题和坐标轴标签
#plt.title("The Correlation of Experiment and Rosetta",fontsize=11)
plt.xlabel('Experimental $\Delta$G (kcal mol$^{-1}$)')
plt.ylabel('Rosetta $\Delta$G (kcal mol$^{-1}$)')
#plt.xticks(fontsize=10)
#plt.yticks(fontsize=10)
plt.xlim([-14,-9])
plt.ylim([-35,-10])
#plt.legend(loc=1,fontsize=5)
# 加相关性数据
#plt.text(0.45, 0.1, "Correlation coefficient: {:.4f}".format(corr), transform=plt.gca().transAxes,fontsize=8)
#plt.text(0.6, 0.05, "$r^2$: {:.4f}".format(corr**2), transform=plt.gca().transAxes,fontsize=8)
# 显⽰图象
#plt.show()
plt.savefig('/home/teliu/work/nanobody/image/draft/fig4/2p4x-all-rosetta.png',bbox_inches='tight',transparent=True)
# Out:
# <>:26: SyntaxWarning: invalid escape sequence '\D'
# <>:27: SyntaxWarning: invalid escape sequence '\D'
# <>:26: SyntaxWarning: invalid escape sequence '\D'
# <>:27: SyntaxWarning: invalid escape sequence '\D'
# /tmp/ipykernel_163989/239529477.py:26: SyntaxWarning: invalid escape sequence '\D'
#   plt.xlabel('Experimental $\Delta$G (kcal mol$^{-1}$)')
# /tmp/ipykernel_163989/239529477.py:27: SyntaxWarning: invalid escape sequence '\D'
#   plt.ylabel('Rosetta $\Delta$G (kcal mol$^{-1}$)')

# %%
np.mean([0.451,0.386,0.481,0.344,0.281,0.511,0.360,0.599,0.360,0.570])
# Out:
# 0.4343

# %%
#7z1x average RMSF Difference (monomer - complex) 290K
plt.figure(figsize=(2,0.3),dpi=300)
plt.tick_params(axis='both', which='major', width=0.5, length=2)
energy_data = [0.451,0.386,0.481,0.344,0.281,0.511,0.360,0.599,0.360,0.570]
width = 0.7
labels = ['7Z1A','7Z1B','7Z1C','7Z1D','7Z1E','H11D4','H11H4','H11H4Y101A','H11H4Y104F','H11H4Y104S']
#plt.ylabel('Average RMSF Difference ($\AA$)',fontsize=10)
#colors=['green','blue','royalblue','cornflowerblue','skyblue','black','lightsalmon','salmon','tomato','red']
colors=['#7FCBBC','#FBFFA5','#F8A452','#F5695E','#D0D0D0','#6DA1C8','#B3ACD3','#F7BFDD','#A8D958','#50E2DE']
barlist = plt.bar(labels,energy_data,width)
plt.xticks(labels, rotation=20,)
#plt.yticks(range(-1,10,10),fontsize=8)
for i, j in enumerate(barlist):
    j.set_color(colors[i])
plt.ylim([0,1])
#plt.title('290K',fontsize=9)
plt.axhline(0.434,color='black',lw=0.5,ls='--')
plt.text(0.01, 0.55, "0.434", transform=plt.gca().transAxes,fontsize=4)
#plt.savefig('/home/teliu/work/nanobody/image/draft/fig4/abs/abs-7z1x-290k.png',bbox_inches='tight',transparent=True)

# %%
np.mean([0.372,0.407,0.375,0.363,0.514,0.434,0.346,0.421,0.423,0.378])
# Out:
# 0.40329999999999994

# %%
#7z1x average RMSF Difference (monomer - complex) 300K
plt.figure(figsize=(2,0.3),dpi=300)
plt.tick_params(axis='both', which='major', width=0.5, length=2)
energy_data = [0.372,0.407,0.375,0.363,0.514,0.434,0.346,0.421,0.423,0.378]
width = 0.7
labels = ['7Z1A','7Z1B','7Z1C','7Z1D','7Z1E','H11D4','H11H4','H11H4Y101A','H11H4Y104F','H11H4Y104S']
#plt.ylabel('Average RMSF Difference ($\AA$)',fontsize=10)
#colors=['green','blue','royalblue','cornflowerblue','skyblue','black','lightsalmon','salmon','tomato','red']
colors=['#7FCBBC','#FBFFA5','#F8A452','#F5695E','#D0D0D0','#6DA1C8','#B3ACD3','#F7BFDD','#A8D958','#50E2DE']
barlist = plt.bar(labels,energy_data,width)
plt.xticks(labels, rotation=20)
#plt.yticks(range(-1,10,10),fontsize=8)
for i, j in enumerate(barlist):
    j.set_color(colors[i])
plt.ylim([0,1])
#plt.title('300K',fontsize=9)
plt.axhline(0.403,color='black',lw=0.5,ls='--')
plt.text(0.01, 0.5, "0.403", transform=plt.gca().transAxes,fontsize=4)
#plt.savefig('/home/teliu/work/nanobody/image/draft/fig4/abs/abs-7z1x-300k.png',bbox_inches='tight',transparent=True)

# %%
np.mean([0.859,0.385,0.425,0.480,0.702,0.381,0.456,0.497,0.803,0.370])
# Out:
# 0.5358

# %%
#7z1x average RMSF Difference (monomer - complex) 315K
plt.figure(figsize=(2,0.3),dpi=300)
plt.tick_params(axis='both', which='major', width=0.5, length=2)
energy_data = [0.859,0.385,0.425,0.480,0.702,0.381,0.456,0.497,0.803,0.370]
width = 0.7
labels = ['7Z1A','7Z1B','7Z1C','7Z1D','7Z1E','H11D4','H11H4','H11H4Y101A','H11H4Y104F','H11H4Y104S']
#plt.ylabel('Average RMSF Difference ($\AA$)',fontsize=10)
#colors=['green','blue','royalblue','cornflowerblue','skyblue','black','lightsalmon','salmon','tomato','red']
colors=['#7FCBBC','#FBFFA5','#F8A452','#F5695E','#D0D0D0','#6DA1C8','#B3ACD3','#F7BFDD','#A8D958','#50E2DE']
barlist = plt.bar(labels,energy_data,width)
plt.xticks(labels, rotation=20)
#plt.yticks(range(-1,10,10),fontsize=8)
for i, j in enumerate(barlist):
    j.set_color(colors[i])
plt.ylim([0,1])
#plt.title('315K',fontsize=9)
plt.axhline(0.536,color='black',lw=0.5,ls='--')
plt.text(0.01, 0.65, "0.536", transform=plt.gca().transAxes,fontsize=4)
#plt.savefig('/home/teliu/work/nanobody/image/draft/fig4/abs/abs-7z1x-315k.png',bbox_inches='tight',transparent=True)
# Out:
# Text(0.01, 0.65, '0.536')

# %%
np.mean([0.377,0.348,0.348,0.356,0.329,0.381,0.336,0.308,0.272])
# Out:
# 0.33944444444444444

# %%
#2p4x average RMSF Difference (monomer - complex) 290K
plt.figure(figsize=(2,0.3),dpi=300)
plt.tick_params(axis='both', which='major', width=0.5, length=2)
energy_data = [0.377,0.348,0.348,0.356,0.329,0.381,0.336,0.308,0.272]
width = 0.7
labels = ['2P42','2P43','2P44','2P45','2P46','2P47','2P48','2P49','2P4A']
#plt.ylabel('Average RMSF Difference ($\AA$)',fontsize=10)
#colors=['green','blue','royalblue','cornflowerblue','skyblue','lightsalmon','salmon','tomato','red']
colors=['#7FCBBC','#FBFFA5','#F8A452','#F5695E','#D0D0D0','#6DA1C8','#B3ACD3','#F7BFDD','#A8D958','#50E2DE']
barlist = plt.bar(labels,energy_data,width)
plt.xticks(labels, rotation=20)
#plt.yticks(range(-1,10,10),fontsize=8)
for i, j in enumerate(barlist):
    j.set_color(colors[i])
plt.ylim([0,1])
#plt.title('290K',fontsize=9)
plt.axhline(0.339,color='black',lw=0.5,ls='--')
plt.text(0.01, 0.45, "0.339", transform=plt.gca().transAxes,fontsize=4)
#plt.savefig('/home/teliu/work/nanobody/image/draft/fig4/abs/abs-2p4x-290k.png',bbox_inches='tight',transparent=True)

# %%
np.mean([0.314,0.258,0.260,0.399,0.332,0.279,0.364,0.263,0.260])
# Out:
# 0.3032222222222222

# %%
#2p4x average RMSF Difference (monomer - complex) 300K
plt.figure(figsize=(2,0.3),dpi=300)
plt.tick_params(axis='both', which='major', width=0.5, length=2)
energy_data = [0.314,0.258,0.260,0.399,0.332,0.279,0.364,0.263,0.260]
width = 0.7
labels = ['2P42','2P43','2P44','2P45','2P46','2P47','2P48','2P49','2P4A']
#plt.ylabel('Average RMSF Difference ($\AA$)',fontsize=10)
#colors=['green','blue','royalblue','cornflowerblue','skyblue','lightsalmon','salmon','tomato','red']
colors=['#7FCBBC','#FBFFA5','#F8A452','#F5695E','#D0D0D0','#6DA1C8','#B3ACD3','#F7BFDD','#A8D958','#50E2DE']
barlist = plt.bar(labels,energy_data,width)
plt.xticks(labels, rotation=20)
#plt.yticks(range(-1,10,10),fontsize=8)
for i, j in enumerate(barlist):
    j.set_color(colors[i])
plt.ylim([0,1])
#plt.title('300K',fontsize=9)
plt.axhline(0.303,color='black',lw=0.5,ls='--')
plt.text(0.01, 0.4, "0.303", transform=plt.gca().transAxes,fontsize=4)
#plt.savefig('/home/teliu/work/nanobody/image/draft/fig4/abs/abs-2p4x-300k.png',bbox_inches='tight',transparent=True)

# %%
np.mean([0.363,0.309,0.335,0.339,0.322,0.337,0.368,0.301,0.322])
# Out:
# 0.33288888888888896

# %%
#2p4x average RMSF Difference (monomer - complex) 315K
plt.figure(figsize=(2,0.3),dpi=300)
plt.tick_params(axis='both', which='major', width=0.5, length=2)
energy_data = [0.363,0.309,0.335,0.339,0.322,0.337,0.368,0.301,0.322]
width = 0.7
labels = ['2P42','2P43','2P44','2P45','2P46','2P47','2P48','2P49','2P4A']
#plt.ylabel('Average RMSF Difference ($\AA$)',fontsize=10)
#colors=['green','blue','royalblue','cornflowerblue','skyblue','lightsalmon','salmon','tomato','red']
colors=['#7FCBBC','#FBFFA5','#F8A452','#F5695E','#D0D0D0','#6DA1C8','#B3ACD3','#F7BFDD','#A8D958','#50E2DE']
barlist = plt.bar(labels,energy_data,width)
plt.xticks(labels, rotation=20)
for i, j in enumerate(barlist):
    j.set_color(colors[i])
plt.ylim([0,1])
#plt.title('315K',fontsize=9)
plt.axhline(0.333,color='black',lw=0.5,ls='--')
plt.text(0.01, 0.45, "0.333", transform=plt.gca().transAxes,fontsize=4)
#plt.savefig('/home/teliu/work/nanobody/image/draft/fig4/abs/abs-2p4x-315k.png',bbox_inches='tight',transparent=True)
