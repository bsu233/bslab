# %%
import matplotlib.pylab as plt
import numpy as np
from matplotlib.colors import ListedColormap, LinearSegmentedColormap
import matplotlib as mpl
import seaborn as sns
#import scienceplots as sp
#plt.style.use(['nature'])
from scipy import stats

# %%
plt.rcParams.update({
    'font.size':10,
    'axes.labelsize':10,
    'axes.titlesize':6,
    'legend.fontsize':10,
    'xtick.labelsize':10,
    'ytick.labelsize':10,
    'figure.dpi':300,
    'savefig.dpi':300,
    'axes.linewidth':0.5,
    'lines.linewidth':1,
})
plt.rcParams['axes.labelpad'] = 1     # 坐标轴标签距离
plt.rcParams['xtick.major.pad'] = 2     # X轴主刻度标签距离
plt.rcParams['ytick.major.pad'] = 2     # Y轴主刻度标签距离
plt.rcParams['axes.titlepad'] = 6      # 标题距离

plt.rcParams['axes.spines.top'] = False
plt.rcParams['axes.spines.right'] = False

# %%
cm = 1/2.54

# %%
affinity=np.loadtxt('/home/teliu/work/nanobody/score/result/new-exp-rosetta',comments="#")

# %%
plt.figure(figsize=(1.5,1.5),dpi=300)
plt.tick_params(axis='both', which='major', width=0.5, length=2)
sns.kdeplot(affinity[:,0],color='#6DA1C8',lw=0.5,fill=True,alpha=0.1)
plt.xlim(-20,-5)
plt.ylim(0,0.25)
plt.xlabel('Experimental Affinity (kcal mol$^{-1}$)')
#plt.savefig('/home/teliu/work/nanobody/image/draft/fig1/affinity.png',bbox_inches='tight',transparent=True)
# Out:
# Text(0.5, 0, 'Experimental Affinity (kcal mol$^{-1}$)')

# %%
plt.figure(figsize=(9*cm,9*cm),dpi=300)
plt.tick_params(axis='both', which='major', width=0.5, length=2)
y = np.array([5, 78])

plt.pie(y,
#        labels=['A','B','C','D'], # 设置饼图标签
        colors=["green", "#5d8ca8"], # 设置饼图颜色
#        explode=(0, 0.2,), # 第二部分突出显示，值越大，距离中心越远
        autopct='%.2f%%', # 格式化输出百分比
                wedgeprops={'edgecolor':'black',#内外框颜色
                    'linestyle':'-',#线型
                    'linewidth':0.3,
                    'alpha':0.5,#透明度
                    }
       )
plt.savefig('/home/teliu/work/nanobody/image/draft/fig1/bing.png',bbox_inches='tight',transparent=True)

# %%
#4krp
nb4krp=np.loadtxt('/home/teliu/work/nanobody/temp/rosetta/4krp/rms_isc.dat',comments="#")
red4krp=np.loadtxt('/home/teliu/work/nanobody/temp/rosetta/4krp/red.dat',comments="#")

plt.figure(figsize=(8*cm,7*cm),dpi=300)

plt.scatter(nb4krp[:,0], nb4krp[:,1],color='grey',s=4)
plt.scatter(red4krp[:,0],red4krp[:,1],color='red',s=4)
#plt.title("4KRP",fontsize=11)
#plt.xticks(fontsize=8)
#plt.yticks(fontsize=8)
plt.xlabel("Interface RMS ($\AA$)",fontsize=10)
plt.ylabel("Interface Energy (kcal mol$^{-1}$)",fontsize=10)
plt.xlim(-1,50)
plt.ylim(-40,1)
plt.savefig('/home/teliu/work/nanobody/image/draft/fig1/4krp.png',bbox_inches='tight',transparent=True)
# Out:
# <>:12: SyntaxWarning: invalid escape sequence '\A'
# <>:12: SyntaxWarning: invalid escape sequence '\A'
# /tmp/ipykernel_105981/696195837.py:12: SyntaxWarning: invalid escape sequence '\A'
#   plt.xlabel("Interface RMS ($\AA$)",fontsize=10)

# %%
test=np.loadtxt('/home/teliu/work/nanobody/temp/rosetta/1g6v/rms_isc.dat',comments="#")
test1=np.loadtxt('/home/teliu/work/nanobody/temp/rosetta/1g6v/red',comments="#")

#1g6v
plt.figure(figsize=(8*cm,7*cm),dpi=300)

x=test[:,0]
y=test[:,1]
plt.scatter(x, y,color='grey',s=4)
plt.scatter(test1[:,0],test1[:,1],color='red',s=4)
#plt.title("1G6V",fontsize=11)
#plt.xticks(fontsize=8)
#plt.yticks(fontsize=8)
plt.xlabel("Interface RMS ($\AA$)",fontsize=10)
plt.ylabel("Interface Energy (kcal mol$^{-1}$)",fontsize=10)
plt.xlim(-1,50)
plt.ylim(-40,1)
plt.savefig('/home/teliu/work/nanobody/image/draft/fig1/1g6v.png',bbox_inches='tight',transparent=True)
# Out:
# <>:14: SyntaxWarning: invalid escape sequence '\A'
# <>:14: SyntaxWarning: invalid escape sequence '\A'
# /tmp/ipykernel_105981/2543348294.py:14: SyntaxWarning: invalid escape sequence '\A'
#   plt.xlabel("Interface RMS ($\AA$)",fontsize=10)
